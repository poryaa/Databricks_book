# %%
# Create a Unity Catalog Volume
spark.sql("CREATE VOLUME IF NOT EXISTS porya_catalog.default.cv_clf")
# Sets the file path variable 
volume_file_path = "/Volumes/porya_catalog/default/cv_clf"

# %%
# %pip install kaggle

# %%
import os
import shutil

# 1. Upload your kaggle.json to the volume, then set the path here
kaggle_json_path = f"./kaggle.json"

# 2. Copy kaggle.json to ~/.kaggle/ (required by the Kaggle API)
os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)
shutil.copy(kaggle_json_path, os.path.expanduser("~/.kaggle/kaggle.json"))
os.chmod(os.path.expanduser("~/.kaggle/kaggle.json"), 0o600)

# %%
# 3. Download the dataset from Kaggle
output_dir = f"{volume_file_path}/intel_image_clf/raw_images"
os.makedirs(output_dir, exist_ok=True)

# !kaggle datasets download -d puneet6060/intel-image-classification -p {output_dir} --unzip
